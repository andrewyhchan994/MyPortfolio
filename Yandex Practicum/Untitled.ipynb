# %%
#     cond1em = (arg['education'].isin(["bachelor's degree", 'graduate degree'])) &(arg['income_type'] == 'employee') &(arg['gender'] == 'M')
#     cond1ef = (arg['education'].isin(["bachelor's degree", 'graduate degree'])) &(arg['income_type'] == 'employee') &(arg['gender'] == 'F')             
#     cond1bm = (arg['education'].isin(["bachelor's degree", 'graduate degree'])) &(arg['income_type'] == 'business') &(arg['gender'] == 'M')
#     cond1bf = (arg['education'].isin(["bachelor's degree", 'graduate degree'])) &(arg['income_type'] == 'business') &(arg['gender'] == 'F')
#     cond1rm = (arg['education'].isin(["bachelor's degree", 'graduate degree'])) &(arg['income_type'] == 'retiree') &(arg['gender'] == 'M')         
#     cond1rf = (arg['education'].isin(["bachelor's degree", 'graduate degree'])) &(arg['income_type'] == 'retiree') &(arg['gender'] == 'M')          

#     cond2em = (arg['education'] == 'primary education') &(arg['income_type'] == 'employee') &(arg['gender'] == 'M')
#     cond2ef = (arg['education'] == 'primary education') &(arg['income_type'] == 'employee') &(arg['gender'] == 'F') 
#     cond2bm = (arg['education'] == 'primary education') &(arg['income_type'] == 'business') &(arg['gender'] == 'M')
#     cond2bf = (arg['education'] == 'primary education') &(arg['income_type'] == 'business') &(arg['gender'] == 'F')
#     cond2rm = (arg['education'] == 'primary education') &(arg['income_type'] == 'retiree') &(arg['gender'] == 'M') 
#     cond2rf = (arg['education'] == 'primary education') &(arg['income_type'] == 'retiree') &(arg['gender'] == 'F') 
              
#     cond3em = (arg['education'] == 'primary education') &(arg['income_type'] == 'employee') &(arg['gender'] == 'M') 
#     cond3ef = (arg['education'] == 'primary education') &(arg['income_type'] == 'employee') &(arg['gender'] == 'F')
#     cond3bm = (arg['education'] == 'primary education') &(arg['income_type'] == 'business') &(arg['gender'] == 'M') 
#     cond3bf = (arg['education'] == 'primary education') &(arg['income_type'] == 'business') &(arg['gender'] == 'F')
#     cond3rm = (arg['education'] == 'primary education') &(arg['income_type'] == 'retiree') &(arg['gender'] == 'M') 
#     cond3rf = (arg['education'] == 'primary education') &(arg['income_type'] == 'retiree') &(arg['gender'] == 'F') 
                
#     cond4em = (arg['education'].isin(["secondary education", 'some college'])) &(arg['income_type'] == 'employee') &(arg['gender'] == 'M') 
#     cond4ef = (arg['education'].isin(["secondary education", 'some college'])) &(arg['income_type'] == 'employee') &(arg['gender'] == 'F') 
#     cond4bm = (arg['education'].isin(["secondary education", 'some college'])) &(arg['income_type'] == 'business') &(arg['gender'] == 'M') 
#     cond4bf = (arg['education'].isin(["secondary education", 'some college'])) &(arg['income_type'] == 'business') &(arg['gender'] == 'F')
#     cond4rm = (arg['education'].isin(["secondary education", 'some college'])) &(arg['income_type'] == 'retiree') &(arg['gender'] == 'M') 
#     cond4rf = (arg['education'].isin(["secondary education", 'some college'])) &(arg['income_type'] == 'retiree') &(arg['gender'] == 'F') 
 
#     arg.loc[cond1em, 'total_income'] = arg.loc[cond1em, 'total_income'].fillna(arg.loc[cond1em, 'total_income'].median())
#     arg.loc[cond1ef, 'total_income'] = arg.loc[cond1ef, 'total_income'].fillna(arg.loc[cond1ef, 'total_income'].median())
#     arg.loc[cond1bm, 'total_income'] = arg.loc[cond1bm, 'total_income'].fillna(arg.loc[cond1bm, 'total_income'].median())
#     arg.loc[cond1bf, 'total_income'] = arg.loc[cond1bf, 'total_income'].fillna(arg.loc[cond1bf, 'total_income'].median())
#     arg.loc[cond1rm, 'total_income'] = arg.loc[cond1rm, 'total_income'].fillna(arg.loc[cond1rm, 'total_income'].median())
#     arg.loc[cond1rf, 'total_income'] = arg.loc[cond1rf, 'total_income'].fillna(arg.loc[cond1rf, 'total_income'].median())
                        
#     arg.loc[cond2em, 'total_income'] = arg.loc[cond2em, 'total_income'].fillna(arg.loc[cond2em, 'total_income'].median())
#     arg.loc[cond2ef, 'total_income'] = arg.loc[cond2ef, 'total_income'].fillna(arg.loc[cond2ef, 'total_income'].median())
#     arg.loc[cond2bm, 'total_income'] = arg.loc[cond2bm, 'total_income'].fillna(arg.loc[cond2bm, 'total_income'].median())
#     arg.loc[cond2bf, 'total_income'] = arg.loc[cond2bf, 'total_income'].fillna(arg.loc[cond2bf, 'total_income'].median())
#     arg.loc[cond2rm, 'total_income'] = arg.loc[cond2rm, 'total_income'].fillna(arg.loc[cond2rm, 'total_income'].median())
#     arg.loc[cond2rf, 'total_income'] = arg.loc[cond2rf, 'total_income'].fillna(arg.loc[cond2rf, 'total_income'].median())
                
#     arg.loc[cond3em, 'total_income'] = arg.loc[cond3em, 'total_income'].fillna(arg.loc[cond3em, 'total_income'].median())
#     arg.loc[cond3ef, 'total_income'] = arg.loc[cond3ef, 'total_income'].fillna(arg.loc[cond3ef, 'total_income'].median())
#     arg.loc[cond3bm, 'total_income'] = arg.loc[cond3bm, 'total_income'].fillna(arg.loc[cond3bm, 'total_income'].median())
#     arg.loc[cond3bf, 'total_income'] = arg.loc[cond3bf, 'total_income'].fillna(arg.loc[cond3bf, 'total_income'].median())
#     arg.loc[cond3rm, 'total_income'] = arg.loc[cond3rm, 'total_income'].fillna(arg.loc[cond3rm, 'total_income'].median())
#     arg.loc[cond3rf, 'total_income'] = arg.loc[cond3rf, 'total_income'].fillna(arg.loc[cond3rf, 'total_income'].median())
    
#     arg.loc[cond4em, 'total_income'] = arg.loc[cond4em, 'total_income'].fillna(arg.loc[cond4em, 'total_income'].median())
#     arg.loc[cond4ef, 'total_income'] = arg.loc[cond4ef, 'total_income'].fillna(arg.loc[cond4ef, 'total_income'].median())
#     arg.loc[cond4bm, 'total_income'] = arg.loc[cond4bm, 'total_income'].fillna(arg.loc[cond4bm, 'total_income'].median())
#     arg.loc[cond4bf, 'total_income'] = arg.loc[cond4bf, 'total_income'].fillna(arg.loc[cond4bf, 'total_income'].median())
#     arg.loc[cond4rm, 'total_income'] = arg.loc[cond4rm, 'total_income'].fillna(arg.loc[cond4rm, 'total_income'].median())
#     arg.loc[cond4rf, 'total_income'] = arg.loc[cond4rf, 'total_income'].fillna(arg.loc[cond4rf, 'total_income'].median())
    
#     return arg
